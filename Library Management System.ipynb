# %% [markdown]
# # Library Management System

# %%
 #Create a Library Management System

   # 1. Username Password
   # 2. total availables books (math - 0)
   # 3. borrow books
   # 4. return books
   # 5. display borrowed books details along with person's name. 
    
   # increase and decrease the count of books accordingly

# %%
                 print("*"*10,"Welcome to Library Management System","*"*10)
                
                Total_books= {"maths":30,"science":20,"english":25,"computer":40,"hindi":10}
                books_returned={}
                username=(input("enter your username:"))
                if username== "saba":
                    print("correct")
                else:
                    print("incorrect! please try again!")
                password= input("enter your password:")    
                if password=="saba123":
                    print("login successfully!")
                
                else:
                    print("enter a valid password")
                    
                print("""press 1 to view available books
                press 2 to add a book
                press 3 to borrow a book
                press 4 to  return a book
                """) 
                choice= int(input("enter your choice from 1-4:"))
                if choice==1:
                    print(" total available books :", Total_books)

                elif choice == 2:
                    while True:
                        subject = input("which subject you want to add: ")
                        Total_books[subject] += 1

                        repeat = input("do you want to add more book y/n : ")
                        if repeat == "no" or repeat == "n":
                            break
                    print("available books: ",Total_books)

                elif choice == 3:
                    books_borrowed = {}
                    while True:
                        subject = input("which subject you want to borrowed: ")
                        Total_books[subject] -= 1
                        books_borrowed[subject] = 1

                        repeat = input("do you want to borrow other book y/n : ").lower()
                        if repeat == "no" or repeat == "n":
                            break
                    print("-"*30)
                    print("username: ",username)
                    print("books borrowed: ",books_borrowed)
                    print("-"*30)

                elif choice == 4:
                    while True:
                        books_returned = input("which subject you want to return: ")
                        Total_books[subject] += 1

                        repeat = input("do you want to return more book y/n: ").lower()
                        if repeat == "no" or repeat == "n":
                            break
                        print("available books: ",Total_books)
                        print("-"*30)
                        print("username: ",username)
                        print("books returned: ",books_returned)
                        print("-"*30)


                        repeat1 = input("do you want to know more details y/n : ").lower()
                        if repeat1 == "no" or repeat1 == "n":
                            break
                    print("thankyou for coming! visit again! ")
